# %%
import pandas as pd
import random
from datetime import datetime, timedelta
random.seed(42)

names = [
    "Rahul Sharma","Priya Nair","Arjun Mehta","Sneha Iyer","Vikram Patel",
    "Anjali Singh","Rohan Gupta","Divya Krishnan","Aditya Rao","Kavya Menon",
    "Siddharth Joshi","Pooja Reddy","Nikhil Verma","Ananya Pillai","Karthik Subramaniam",
    "Meera Bose","Rohit Agarwal","Swati Desai","Gautam Nambiar","Lakshmi Chandran",
    "Varun Malhotra","Ritu Saxena","Sandeep Kumar","Deepa Varma","Tarun Bhatt",
    "Nisha Tiwari","Amrit Chaudhary","Sonia Kapoor","Vivek Bajaj","Priyanka Mishra",
    "Rajesh Srinivasan","Usha Gopalan","Harish Pandey","Archana Kulkarni","Manish Thakur",
    "Rekha Bhattacharya","Sumit Yadav","Tanya Jain","Akash Chatterjee","Pallavi Mohan",
    "Kunal Dixit","Smita Ghosh","Abhinav Kohli","Lavanya Suresh","Pranav Nair",
    "Shruthi Anand","Anand Murthy","Vidya Seshadri","Nitin Pillai","Geeta Raghavan",
    "Dhruv Kapoor","Simran Bajwa","Aryan Sethi","Neha Tripathi","Ishaan Bhat",
    "Poornima Hegde","Raghav Khanna","Tanvi Dubey","Chirag Shah","Meenal Deshpande",
    "Surya Prakash","Revathi Nambiar","Aakash Goel","Bhavna Choudhary","Tejas Patil",
    "Shweta Mathur","Vignesh Rajan","Aarti Acharya","Mihir Soni","Chandrika Prasad",
    "Yash Malviya","Preethi Venkatesh","Abir Roy","Roshni Aiyar","Saurabh Diwan",
    "Kritika Menon","Devraj Shetty","Nandita Ghoshal","Ashwin Pillai","Farah Irani",
    "Kiran Reddy","Anita Joshi","Piyush Aggarwal","Hemangini Shah","Parth Solanki",
    "Riddhi Kulkarni","Sachin Bhattarai","Meghna Krishnaswamy","Rohit Das","Sheetal Pant",
    "Arun Shankar","Nidhi Lal","Shantanu Trivedi","Pooja Ahuja","Manohar Iyengar",
    "Zara Mirza","Kaushik Nair","Devika Soni","Vinayak Joshi","Trisha Raman",
    "Srinath Balaji","Aishwarya Pai","Prasad Kulkarni","Deepika Menon","Ravi Narayanan"
]

locations = [
    "Bangalore","Mumbai","Chennai","Hyderabad","Pune","Delhi","Kolkata",
    "Ahmedabad","Kochi","Jaipur","Noida","Gurugram","Coimbatore","Mysuru","Chandigarh"
]

professions = [
    "Data Analyst","Software Engineer","Product Manager","UX Designer","Marketing Specialist",
    "Business Analyst","Machine Learning Engineer","Content Strategist","DevOps Engineer",
    "HR Manager","Financial Analyst","Graphic Designer","Full Stack Developer",
    "Operations Manager","Cybersecurity Analyst","Cloud Architect","Data Scientist",
    "Digital Marketing Manager","Backend Developer","Scrum Master","Research Scientist",
    "Project Manager","UI Developer","Sales Manager","Quality Analyst"
]

mbti_types = [
    "INTJ","INTP","ENTJ","ENTP","INFJ","INFP","ENFJ","ENFP",
    "ISTJ","ISFJ","ESTJ","ESFJ","ISTP","ISFP","ESTP","ESFP"
]

profession_mbti = {
    "Data Analyst": ["INTJ","INTP","ISTJ","ENTJ"],
    "Software Engineer": ["INTP","ISTJ","INTJ","ISTP"],
    "Product Manager": ["ENTJ","ENFJ","ENTP","ESTJ"],
    "UX Designer": ["INFP","ENFP","ISFP","INFJ"],
    "Marketing Specialist": ["ENFP","ESFP","ENTP","ESTJ"],
    "Business Analyst": ["ISTJ","INTJ","ENTJ","ESTJ"],
    "Machine Learning Engineer": ["INTP","INTJ","ISTJ","ENTP"],
    "Content Strategist": ["INFP","ENFP","INFJ","ENFJ"],
    "DevOps Engineer": ["ISTJ","ISTP","INTJ","INTP"],
    "HR Manager": ["ENFJ","ESFJ","INFJ","ESTJ"],
    "Financial Analyst": ["ISTJ","INTJ","ESTJ","ENTJ"],
    "Graphic Designer": ["ISFP","INFP","ENFP","ISFJ"],
    "Full Stack Developer": ["INTP","INTJ","ISTP","ISTJ"],
    "Operations Manager": ["ESTJ","ENTJ","ISTJ","ENFJ"],
    "Cybersecurity Analyst": ["INTJ","ISTJ","INTP","ISTP"],
    "Cloud Architect": ["INTJ","INTP","ENTJ","ISTJ"],
    "Data Scientist": ["INTP","INTJ","ENTP","ISTJ"],
    "Digital Marketing Manager": ["ENFP","ENTP","ESFP","ESTJ"],
    "Backend Developer": ["INTJ","INTP","ISTJ","ISTP"],
    "Scrum Master": ["ENFJ","ESTJ","ENTJ","ESFJ"],
    "Research Scientist": ["INTP","INTJ","INFJ","ENTP"],
    "Project Manager": ["ENTJ","ESTJ","ENFJ","ISTJ"],
    "UI Developer": ["ISFP","INFP","INTP","ISFJ"],
    "Sales Manager": ["ESTP","ENFJ","ESFP","ENTJ"],
    "Quality Analyst": ["ISTJ","ISFJ","ESTJ","INTJ"]
}

interests_pool = {
    "tech": ["Machine Learning","Open Source","Cloud Computing","Cybersecurity","Blockchain","IoT","Robotics","AR/VR"],
    "creative": ["Photography","Writing","Graphic Design","Podcasting","Music","Painting","Filmmaking","Creative Writing"],
    "active": ["Fitness","Hiking","Yoga","Swimming","Cycling","Rock Climbing","Martial Arts","Marathon Running"],
    "social": ["Volunteering","Community Building","Mentoring","Networking","Team Sports","Travel","Cooking"],
    "intellectual": ["Reading","Chess","Philosophy","Psychology","Economics","Astronomy","Data Visualization","Public Speaking"]
}

pro_summary_templates = [
    "{prof} with {exp} years of experience in {industry}, specializing in {skill1} and {skill2}. Passionate about {goal} and building scalable solutions that create measurable impact.",
    "Experienced {prof} with {exp}+ years helping {client_type} achieve {outcome}. Skilled in {skill1}, {skill2}, and {skill3}. Currently focused on {goal} in the {industry} space.",
    "{prof} at the intersection of {industry} and {domain2}, with {exp} years of hands-on expertise in {skill1} and {skill2}. Driven by a desire to {goal}.",
    "Results-oriented {prof} with {exp} years in {industry}. Strong background in {skill1} and {skill2}. Looking to collaborate on projects that {goal}.",
    "Dedicated {prof} with {exp} years of experience, specializing in {skill1}, {skill2}, and {skill3}. Passionate about {goal} and continuous learning in the {industry} sector."
]

about_me_templates = [
    "I thrive in collaborative environments where ideas are freely exchanged and everyone is heard. A strong believer in continuous learning, I spend my weekends {interest1} and {interest2}. I value authenticity, empathy, and a healthy work-life balance.",
    "A curious mind who loves tackling complex problems with a structured approach. Outside of work, I enjoy {interest1} and {interest2}. I'm driven by meaningful work, honest conversations, and building long-lasting professional relationships.",
    "I bring a mix of analytical thinking and creative problem-solving to everything I do. When I'm not at my desk, you'll find me {interest1} or exploring {interest2}. I value integrity, teamwork, and a growth mindset above all.",
    "Passionate about making a difference through my work, I believe in the power of collaboration and clear communication. My personal time is spent {interest1} and {interest2}. I look for partners who share a drive for impact and authenticity.",
    "I'm an organized, detail-oriented professional who also values big-picture thinking. Outside work, I'm deeply interested in {interest1} and {interest2}. I appreciate people who are reliable, thoughtful, and eager to grow together.",
    "Known for being approachable and solutions-focused, I enjoy mentoring peers and sharing knowledge freely. My hobbies include {interest1} and {interest2}, which keep me grounded and creative. I value transparency and mutual respect in all collaborations."
]

skills_by_profession = {
    "Data Analyst": ["SQL","Python","Power BI","Tableau","Excel","Statistical Analysis","Data Wrangling"],
    "Software Engineer": ["Java","Python","React","Node.js","System Design","REST APIs","Git"],
    "Product Manager": ["Roadmapping","Agile","User Research","Jira","Stakeholder Management","OKRs"],
    "UX Designer": ["Figma","User Research","Wireframing","Prototyping","Design Systems","Usability Testing"],
    "Marketing Specialist": ["SEO","Content Marketing","Google Analytics","Social Media","Email Campaigns","A/B Testing"],
    "Business Analyst": ["Requirements Gathering","SQL","Process Mapping","Stakeholder Communication","Excel","BPMN"],
    "Machine Learning Engineer": ["Python","TensorFlow","PyTorch","Scikit-learn","MLOps","Feature Engineering"],
    "Content Strategist": ["SEO Writing","Brand Voice","Content Calendar","CMS","Audience Research","Storytelling"],
    "DevOps Engineer": ["Docker","Kubernetes","CI/CD","Terraform","AWS","Linux","Monitoring"],
    "HR Manager": ["Talent Acquisition","Employee Engagement","HRIS","Performance Management","Policy Design"],
    "Financial Analyst": ["Excel","Financial Modeling","Valuation","SQL","Bloomberg","FP&A","Risk Analysis"],
    "Graphic Designer": ["Adobe Illustrator","Photoshop","InDesign","Figma","Branding","Typography"],
    "Full Stack Developer": ["React","Node.js","MongoDB","SQL","Docker","REST APIs","TypeScript"],
    "Operations Manager": ["Process Optimization","Supply Chain","ERP","KPI Tracking","Team Leadership","Lean"],
    "Cybersecurity Analyst": ["Penetration Testing","SIEM","Threat Analysis","Network Security","ISO 27001"],
    "Cloud Architect": ["AWS","Azure","GCP","Terraform","Microservices","Cost Optimization","Security"],
    "Data Scientist": ["Python","R","Machine Learning","NLP","Statistics","Spark","Data Storytelling"],
    "Digital Marketing Manager": ["PPC","SEO","SEM","Meta Ads","Analytics","CRM","Growth Hacking"],
    "Backend Developer": ["Python","Java","Node.js","PostgreSQL","Redis","Microservices","Docker"],
    "Scrum Master": ["Agile","Scrum","Kanban","Jira","Sprint Planning","Retrospectives","Coaching"],
    "Research Scientist": ["Experimental Design","Python","R","Statistical Modeling","Literature Review","Publishing"],
    "Project Manager": ["PMP","Risk Management","MS Project","Budget Planning","Stakeholder Management","Agile"],
    "UI Developer": ["React","CSS","HTML","Figma","Accessibility","Animation","Component Libraries"],
    "Sales Manager": ["CRM","Negotiation","Pipeline Management","Salesforce","Cold Outreach","Revenue Forecasting"],
    "Quality Analyst": ["Test Planning","Selenium","JIRA","SQL","Bug Tracking","Automation","Regression Testing"]
}

industries = {
    "Data Analyst": "healthcare analytics","Software Engineer": "fintech","Product Manager": "SaaS",
    "UX Designer": "edtech","Marketing Specialist": "e-commerce","Business Analyst": "banking",
    "Machine Learning Engineer": "AI research","Content Strategist": "media","DevOps Engineer": "cloud infrastructure",
    "HR Manager": "talent management","Financial Analyst": "investment banking","Graphic Designer": "brand design",
    "Full Stack Developer": "web platforms","Operations Manager": "logistics","Cybersecurity Analyst": "information security",
    "Cloud Architect": "cloud computing","Data Scientist": "predictive analytics","Digital Marketing Manager": "growth marketing",
    "Backend Developer": "distributed systems","Scrum Master": "agile delivery","Research Scientist": "applied research",
    "Project Manager": "enterprise software","UI Developer": "front-end engineering","Sales Manager": "B2B sales",
    "Quality Analyst": "software quality"
}

goals = [
    "drive innovation through data","build products that scale globally","mentor the next generation of tech professionals",
    "bridge the gap between design and engineering","create inclusive digital experiences","leverage AI to solve real-world problems",
    "lead cross-functional teams toward meaningful outcomes","transform raw data into actionable insights",
    "streamline operations for efficiency and growth","build resilient and secure systems"
]

client_types = ["startups","enterprise clients","non-profits","healthcare organizations","fintech companies","e-commerce brands"]
outcomes = ["digital transformation","revenue growth","operational efficiency","user retention","process automation"]
domains2 = ["data engineering","product strategy","user experience","cloud infrastructure","behavioral analytics"]

def pick_interests():
    categories = random.sample(list(interests_pool.keys()), 2)
    i1 = random.choice(interests_pool[categories[0]])
    i2 = random.choice(interests_pool[categories[1]])
    return i1, i2

def make_summary(prof, exp):
    tmpl = random.choice(pro_summary_templates)
    skills = skills_by_profession.get(prof, ["communication","analysis","strategy"])
    random.shuffle(skills)
    return tmpl.format(
        prof=prof, exp=exp,
        industry=industries.get(prof,"technology"),
        skill1=skills[0], skill2=skills[1],
        skill3=skills[2] if len(skills) > 2 else "leadership",
        goal=random.choice(goals),
        client_type=random.choice(client_types),
        outcome=random.choice(outcomes),
        domain2=random.choice(domains2)
    )

def make_about(i1, i2):
    tmpl = random.choice(about_me_templates)
    return tmpl.format(interest1=i1.lower(), interest2=i2.lower())

def make_interests(i1, i2):
    extras = []
    for cat in interests_pool.values():
        extras.extend(cat)
    extra = random.choice([x for x in extras if x not in [i1, i2]])
    return f"{i1}, {i2}, {extra}"

users = []
used_names = random.sample(names, 100)
for idx in range(100):
    uid = f"U{idx+1:03d}"
    name = used_names[idx]
    age = random.randint(22, 45)
    loc = random.choice(locations)
    prof = random.choice(professions)
    exp = random.randint(1, min(age - 20, 15))
    exp = max(1, exp)
    mbti_choices = profession_mbti.get(prof, mbti_types)
    mbti = random.choice(mbti_choices)
    i1, i2 = pick_interests()
    summary = make_summary(prof, exp)
    about = make_about(i1, i2)
    ints = make_interests(i1, i2)
    users.append({
        "user_id": uid, "name": name, "age": age, "location": loc,
        "profession": prof, "experience_years": exp,
        "professional_summary": summary, "about_me": about,
        "mbti": mbti, "interests": ints
    })

users_df = pd.DataFrame(users)
users_df.to_csv("data/users.csv", index=False)
print(f"users.csv: {len(users_df)} rows")
# Out:
# users.csv: 100 rows
